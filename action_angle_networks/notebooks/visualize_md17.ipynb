# %%
## Imports
import numpy as np
import jax
import matplotlib
from matplotlib import animation
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import os
from sklearn import decomposition
import scipy.interpolate
import sys
sys.path.append("..")

from action_angle_networks.simulation import md17_simulation
matplotlib.rc("animation", html="jshtml")
PLT_STYLE_CONTEXT = ['science', 'ieee', 'grid']

# %%
# %load_ext autoreload

# %%
# @title Source Imports
# %autoreload 2
from action_angle_networks.simulation import md17_simulation

# %%
def visualize_trajectory(molecule: str, num_structures: int = 100, resample: bool = False):
    """Visualizes a molecular dynamics trajectory."""

    # Load trajectory
    positions, _, nuclear_charges = md17_simulation.load_trajectory(molecule, 10000000, resample)
    # Project down to two dimensions.
    num_atoms = positions.shape[1]
    positions_flat = positions.reshape(-1, 3)
    projected_positions_flat = decomposition.PCA(n_components=2).fit_transform(positions_flat)
    projected_positions = np.reshape(projected_positions_flat, (-1, num_atoms, 2))

    # Plot.
    with plt.style.context(PLT_STYLE_CONTEXT):
        fig, ax = plt.subplots()
        scatter = ax.scatter(projected_positions[0, :, 0], projected_positions[0, :, 1], c=plt.cm.tab20(nuclear_charges))
        handles = []
        for nuclear_charge in set(nuclear_charges):
            element = md17_simulation.charge_to_element(nuclear_charge)
            handle = mlines.Line2D([], [], color=plt.cm.tab20(nuclear_charge), marker='o', ls='', label=element)
            handles.append(handle)
        ax.legend(handles=handles, loc="upper right")
        ax.set_xlabel("x")
        ax.set_ylabel("y")
        ax.set_xlim(1.5 * v for v in ax.get_xlim())
        ax.set_ylim(1.5 * v for v in ax.get_ylim())
        ax.set_title(f"MD17: {molecule.capitalize()}")
        ax.grid(False)
        fig.tight_layout()

        def init():
            return scatter,
            
        def plot_structure(index):
            scatter.set_offsets(projected_positions[index, :])
            return scatter,

        anim = animation.FuncAnimation(fig, plot_structure, init_func=init, frames=num_structures, interval=100, blit=True)

    plt.close()
    return anim

# %%
from IPython.display import HTML
HTML(anim.to_jshml())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from IPython.display import HTML
# ----> 2 HTML(anim.to_jshml())
#
# NameError: name 'anim' is not defined

# %%
for molecule in ["benzene", "ethanol", "aspirin", "toluene"]:
    md17_simulation.load_trajectory(molecule, 100000000, resample=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 for molecule in ["benzene", "ethanol", "aspirin", "toluene"]:
# ----> 2     md17_simulation.load_trajectory(molecule, 100000000, resample=False)
#
# File ~/ActionAngleNetworks/action_angle_networks/simulation/md17_simulation.py:39, in load_trajectory(molecule, num_samples, resample)
#      37 # Load sample of trajectory.
#      38 molecule_path = os.path.join(_MD17_BASE_PATH, f"rmd17_{molecule}.npz")
# ---> 39 with np.load(molecule_path) as data:
#      40     indices = data["old_indices"]
#      41     print("indices", indices, len(indices))
#
# File /usr/local/lib/python3.12/dist-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ameyad/Documents/google-research/data/MD17/npz_data/rmd17_benzene.npz'

# %%
for molecule in ["benzene", "ethanol", "aspirin", "toluene"]:
    anim = visualize_trajectory(molecule, resample=True)
    # anim.save(f"../notebook_outputs/{molecule}.gif")
    # anim
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 for molecule in ["benzene", "ethanol", "aspirin", "toluene"]:
# ----> 2     anim = visualize_trajectory(molecule, resample=True)
#       3     # anim.save(f"../notebook_outputs/{molecule}.gif")
#       4     # anim
#
# Cell In[4], line 5, in visualize_trajectory(molecule, num_structures, resample)
#       2 """Visualizes a molecular dynamics trajectory."""
#       4 # Load trajectory
# ----> 5 positions, _, nuclear_charges = md17_simulation.load_trajectory(molecule, 10000000, resample)
#       6 # Project down to two dimensions.
#       7 num_atoms = positions.shape[1]
#
# File ~/ActionAngleNetworks/action_angle_networks/simulation/md17_simulation.py:39, in load_trajectory(molecule, num_samples, resample)
#      37 # Load sample of trajectory.
#      38 molecule_path = os.path.join(_MD17_BASE_PATH, f"rmd17_{molecule}.npz")
# ---> 39 with np.load(molecule_path) as data:
#      40     indices = data["old_indices"]
#      41     print("indices", indices, len(indices))
#
# File /usr/local/lib/python3.12/dist-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ameyad/Documents/google-research/data/MD17/npz_data/rmd17_benzene.npz'
